# %% [markdown]
# <a href="https://colab.research.google.com/github/arya-n-raj/Find_Funky/blob/main/yolo_train_v8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.5/586.5 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 24.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.predict(
   source='https://media.roboflow.com/notebooks/examples/dog.jpeg',
   conf=0.25
)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 69.6MB/s]
#
# ...
# 100%|██████████| 104k/104k [00:00<00:00, 5.87MB/s]
# image 1/1 /root/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 57.7ms
# Speed: 13.4ms preprocess, 57.7ms inference, 42.8ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SmZafFaLVETCtmx0Ucvd")
project = rf.workspace("cd-1qlyv").project("funko-v2")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.105, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Funko-v2-1 in yolov8:: 100%|██████████| 620/620 [00:00<00:00, 2318.89it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=640
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cd /root/runs/detect/train

# %%
# !ls
# Out:
# dog.jpeg  Funko-v2-1  runs  yolov8n.pt	yolov8s.pt

# %%
# !yolo task=detect mode=predict model=/root/runs/detect/train/weights/best.pt conf=0.25 source=/testvideo.mp4
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# video 1/1 (1/447) /testvideo.mp4: 640x384 2 Funkos, 57.0ms
# video 1/1 (2/447) /testvideo.mp4: 640x384 2 Funkos, 10.9ms
# video 1/1 (3/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (4/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (5/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (6/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (7/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (8/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (9/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (10/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (11/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (12/447) /testvideo.mp4: 640x384 2 Funkos, 10.8ms
# video 1/1 (13/447) /testvideo.mp4: 640x384 1 Funko, 10.8ms
# ...

# %%
# !ls
# Out:
# dog.jpeg  Funko-v2-1  {HOME}  README.md  runs  yolov8n.pt  yolov8s.pt
